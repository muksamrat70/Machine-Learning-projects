# %%
# %reset -f 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
sp = pd.read_csv("/Users/sm/Desktop/DataExploration/superstore_dataset2011-2015.csv",encoding="ISO-8859-1")

# %%
x = sp.sort_values('Profit', ascending=False)
top20 = x.head(20)
top20[['Customer Name', 'Profit']]                #top 20 profitable customers at the superstore
# Out:
#               Customer Name     Profit
# 8898           Tamara Chand  8399.9760
# 38848          Raymond Buch  6719.9808
# 29946          Hunter Lopez  5039.9856
# 30124         Adrian Barton  4946.3700
# 37929          Sanjit Chand  4630.4755
# 17421         Patrick Jones  3979.0800
# 38234          Tom Ashbrook  3919.9888
# 25346  Christopher Martinez  3177.4750
# 2756            Carol Adams  2939.3100
# 12813       Cynthia Arntzen  2817.9900
# 8209           Sanjit Engle  2799.9840
# 46854          Dave Poirier  2597.2800
# 9832          Daniel Raglin  2591.9568
# 26821           Andy Reiter  2504.2216
# 2273      Elpida Rittenbach  2476.4400
# 47650       Mike Gockenbach  2461.3200
# 26639            Ann Steele  2447.1000
# 8225          Karen Daniels  2400.9657
# 27043          Bill Shonely  2365.9818
# 39239       Maria Bertelson  2316.5100

# %%
sns.barplot(x = "Customer Name", y= "Profit", data=top20)  # plotting of top 20 profitable customers

# %%
sns.countplot("Segment", data = sp)           #Distribution of custome Segment

# %%
sp.groupby('Customer ID').apply(lambda x: pd.Series(dict(store_visit=x.shape[0]))).reset_index()
# Out:
#      Customer ID  store_visit
# 0       AA-10315           42
# 1       AA-10375           42
# 2       AA-10480           38
# 3       AA-10645           73
# 4         AA-315            8
# 5         AA-375           13
# 6         AA-480           10
# 7         AA-645           18
# 8       AB-10015           77
# 9       AB-10060           57
# 10      AB-10105           62
# 11      AB-10150           47
# 12      AB-10165           52
# 13      AB-10255           53
# 14        AB-105           15
# 15      AB-10600           38
# 16         AB-15           12
# 17        AB-150            8
# 18        AB-165            8
# 19        AB-255           15
# 20         AB-60           11
# 21        AB-600           26
# 22      AC-10420           40
# 23      AC-10450           29
# 24      AC-10615           65
# 25      AC-10660           35
# 26        AC-420           21
# 27        AC-450           10
# 28        AC-615           18
# 29        AC-660            8
# ...          ...          ...
# 1560    VG-11790            7
# 1561    VG-11805            7
# 1562    VG-21790           43
# 1563    VG-21805           54
# 1564    VM-11685           14
# 1565    VM-11835            7
# 1566    VM-21685           54
# 1567    VM-21835           29
# 1568    VP-11730            9
# 1569    VP-11760            9
# 1570    VP-21730           49
# 1571    VP-21760           51
# 1572    VS-11820           11
# 1573    VS-21820           29
# 1574    VT-11700           11
# 1575    VT-21700           61
# 1576    VW-11775            9
# 1577    VW-21775           57
# 1578    WB-11850            5
# 1579    WB-21850           79
# 1580    XP-11865            6
# 1581    XP-21865           55
# 1582    YC-11895            5
# 1583    YC-21895           51
# 1584    YS-11880            8
# 1585    YS-21880           54
# 1586    ZC-11910            1
# 1587    ZC-21910           84
# 1588    ZD-11925           18
# 1589    ZD-21925           36
#
# [1590 rows x 2 columns]

# %%
sp1 = sp.groupby('Customer ID').apply(lambda x: pd.Series(dict(store_visit=x.shape[0]))).reset_index()
sp1.loc[sp1.store_visit == 1, ['Customer ID', 'store_visit']]     # Customers who have visited the store only once
# Out:
#      Customer ID  store_visit
# 170      BG-1035            1
# 431      DK-2985            1
# 1001     ME-8010            1
# 1013     MG-7650            1
# 1017     MG-7890            1
# 1260     RC-9825            1
# 1586    ZC-11910            1

# %%
sns.boxplot("Order Priority","Profit",data= sp)    # relationship of Order Priority and Profitability : 
                                                   # Profits slightly higher when Order priority is Medium

# %%
sns.countplot("Market",data = sp)                                # distribution of customers marketwise

# %%
sns.countplot("Region", hue= "Market", data = sp)                 # distribution of customers regionwise, marketwise

# %%
y = sp.sort_values(["Order Date"], ascending=True).iloc[0:20,:]                         # top 20 oldest customers

# %%
y["Customer Name"].unique()
# Out:
# array(['Toby Braunhardt', 'Joseph Holt', 'Annie Thurman', 'Eugene Moren',
#        'Chris Cortes', 'Joy Smith', 'Liz Pelletier', 'Jim Radford',
#        'Troy Blackwell', 'Muhammed Yedwab', 'Joe Elijah',
#        'Stephanie Phelps', 'Patrick Bzostek', 'Nora Pelletier'],
#       dtype=object)
